# %%
import sys
sys.path.append("../src")

# %%
from extractor import load_policy, clean_text
from summarizer import summarize_policy

# %%
raw = load_policy("../data/raw/marriot_privacy.txt")
cleaned = clean_text(raw)

summary = summarize_policy(cleaned)

print(summary)
# Out:
# Here’s a simplified summary of the privacy policy in five bullet points:
#
# - **What We Collect**: We gather business-related personal information, like contact details, job information, and online activity, mainly from business representatives, not individuals for personal use.
#
# - **How We Use It**: We use your personal information to improve our services, communicate with you, conduct research, and comply with legal obligations.
#
# - **Sharing Information**: We may share your personal information with affiliated companies, service providers, or legal authorities if needed, but we do not sell your information.
#
# - **Your Choices**: You can opt-out of marketing communications, manage cookie preferences, and request access or deletion of your personal data.
#
# - **Security and Data Transfer**: We implement security measures to protect your data, but note that we may transfer information internationally, which may have different privacy standards.

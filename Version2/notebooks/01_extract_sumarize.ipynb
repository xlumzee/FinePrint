# %%
import sys
sys.path.append("../src")

# %%
from extractor import load_policy, clean_text
from summarizer import summarize_policy
from risk_detector import detect_risk

# %%
raw = load_policy("../data/raw/marriot_privacy.txt")
cleaned = clean_text(raw)

summary = summarize_policy(cleaned)

print(summary)
# Out:
# Here’s a simplified summary of the Marriott Group Global Privacy Statement:
#
# - **Data Collection**: Marriott collects personal information when you make reservations, stay at their properties, and interact with their websites and apps.
#
# - **Data Usage**: This information is used to provide services, enhance your experience, and communicate with you about bookings and promotions.
#
# - **Data Sharing**: Your data may be shared with Marriott's affiliates, franchisees, and third-party partners to facilitate services and marketing.
#
# - **Your Choices**: You have options regarding your data, including opting out of marketing communications, managing cookie preferences, and exercising your rights under data protection laws.
#
# - **Security and Retention**: Marriott uses measures to protect your data but cannot guarantee complete security. Your information is kept only as long as necessary for the services provided.

# %%
raw = load_policy("../data/raw/marriot_privacy.txt")
cleaned = clean_text(raw)

risks = detect_risks(cleaned)
risks
